# %% [markdown]
# In this project I start with comparing songs from a playlist I curate - the PopConnoisseur Playlist - with the Billboard Hot 100 using Spotify's own Track Features: danceability, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo. For more about what those mean:
#
# https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/
#
# It's not the authoritative list of choices that can be taken with this data, just things I thought were fun/interesting.

# %% [markdown]
# Previously I used Spotipy to access Spotify's API and download 1) a list of songs for each of the two playlists, then 2) their Track Features, which I saved to Excel files. Let's import the data into Pandas DataFrames:
#
# pc_data.xlsx is my PopConnoisseur Playlist as of June 10, 2020.
#
# bb_data.xlsx is the Billboard Hot 100 as of June 10, 2020.
#
# We start with importing the "usual suspects" packages for data vis:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bbdf = pd.read_excel('bb_data.xlsx', usecols = "B:S")
pcdf = pd.read_excel('pc_data.xlsx', usecols = "B:S")

# %% [markdown]
# We'll be working with the float and int columns and dropping the string columns.

# %%
pcdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362 entries, 0 to 361
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      362 non-null    float64
#  1   energy            362 non-null    float64
#  2   key               362 non-null    int64
#  3   loudness          362 non-null    float64
#  4   mode              362 non-null    int64
#  5   speechiness       362 non-null    float64
#  6   acousticness      362 non-null    float64
#  7   instrumentalness  362 non-null    float64
#  8   liveness          362 non-null    float64
#  9   valence           362 non-null    float64
#  10  tempo             362 non-null    float64
#  11  type              362 non-null    object
#  12  id                362 non-null    object
#  13  uri               362 non-null    object
#  14  track_href        362 non-null    object
#  15  analysis_url      362 non-null    object
#  16  duration_ms       362 non-null    int64
#  17  time_signature    362 non-null    int64
# dtypes: float64(9), int64(4), object(5)
# memory usage: 51.0+ KB

# %%
pcdf.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.462   0.715   11    -6.829     1       0.0454       0.11800
# 1         0.678   0.607    0    -7.190     1       0.0750       0.17400
# 2         0.623   0.840    7    -3.944     0       0.0799       0.04730
# 3         0.555   0.423    0    -6.232     1       0.0440       0.79900
# 4         0.420   0.879   11    -4.916     0       0.0568       0.00729
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.001030    0.0592    0.237   99.763  audio_features
# 1          0.000000    0.0788    0.445   91.973  audio_features
# 2          0.023400    0.1070    0.788  162.062  audio_features
# 3          0.000000    0.1120    0.257  137.044  audio_features
# 4          0.000085    0.1800    0.432  128.913  audio_features
#
#                        id                                   uri  \
# 0  6D4fpmCAzPMivhDQV1y2rH  spotify:track:6D4fpmCAzPMivhDQV1y2rH
# 1  0sZfuG1rArPovx9CdZ40vZ  spotify:track:0sZfuG1rArPovx9CdZ40vZ
# 2  3zzW1STuSWbyEe76XgP6kp  spotify:track:3zzW1STuSWbyEe76XgP6kp
# 3  5ZT5UB1SNVMkfYiTvnliz4  spotify:track:5ZT5UB1SNVMkfYiTvnliz4
# 4  6Q7mhgiHSay1lwwfnKzgzh  spotify:track:6Q7mhgiHSay1lwwfnKzgzh
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/6D4fpmCAzPMi...
# 1  https://api.spotify.com/v1/tracks/0sZfuG1rArPo...
# 2  https://api.spotify.com/v1/tracks/3zzW1STuSWby...
# 3  https://api.spotify.com/v1/tracks/5ZT5UB1SNVMk...
# 4  https://api.spotify.com/v1/tracks/6Q7mhgiHSay1...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/6D4f...       166788
# 1  https://api.spotify.com/v1/audio-analysis/0sZf...       204418
# 2  https://api.spotify.com/v1/audio-analysis/3zzW...       251627
# 3  https://api.spotify.com/v1/audio-analysis/5ZT5...       202147
# 4  https://api.spotify.com/v1/audio-analysis/6Q7m...       279000
#
#    time_signature
# 0               4
# 1               4
# 2               3
# 3               4
# 4               4

# %% [markdown]
# We can see right off the bat that the scale for these columns is all over the place, including Mode, which is classified either Major, represented by 1, and minor, represented by 0.
#
# Loudness is the decibel (dB) value, measure in number of dB below 0, so values closer to 0 are louder.

# %%
plt.figure(figsize=(10,4))
sns.distplot(pcdf['instrumentalness'])

# %% [markdown]
# Looks like there are a few instrumental-leaning songs on the PopConnoisseur Playlist.
#
# Let's see how many different values for time signature there are. Mostly this is to check the data quality.

# %%
pcdf.time_signature.value_counts()
# Out:
# 4    339
# 3     14
# 5      7
# 1      2
# Name: time_signature, dtype: int64

# %% [markdown]
# I don't like many songs in 5/4 time so this seems odd. Let's investigate by viewing those...

# %%
pcdf[pcdf.time_signature == 5]
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 18          0.586  0.6500    1    -5.912     1       0.3350      0.131000
# 22          0.294  0.0951    5   -12.915     1       0.0373      0.957000
# 31          0.466  0.6660    1    -6.770     1       0.1690      0.000199
# 35          0.344  0.4180    3    -7.811     1       0.0423      0.743000
# 43          0.482  0.4770   10    -8.444     0       0.0503      0.020100
# 247         0.122  0.5490    0    -7.389     1       0.0362      0.630000
# 315         0.544  0.9160    1    -2.742     1       0.2310      0.068700
#
#      instrumentalness  liveness  valence    tempo            type  \
# 18           0.000000    0.0738   0.7010  129.239  audio_features
# 22           0.000032    0.1040   0.1470  167.241  audio_features
# 31           0.019500    0.0803   0.3370  113.935  audio_features
# 35           0.000000    0.1020   0.0766   99.962  audio_features
# 43           0.000000    0.2510   0.3790  117.850  audio_features
# 247          0.015800    0.0908   0.2010   67.327  audio_features
# 315          0.000000    0.3520   0.4540  108.257  audio_features
#
#                          id                                   uri  \
# 18   7jhS5XE7nmgcsTbkcqzTc7  spotify:track:7jhS5XE7nmgcsTbkcqzTc7
# 22   5KmA68mgrZX815hICp1IVP  spotify:track:5KmA68mgrZX815hICp1IVP
# 31   3LRddJIw2ymm1CHIO9xlkC  spotify:track:3LRddJIw2ymm1CHIO9xlkC
# 35   4G9mDvbxpmMNFNXXlLbEot  spotify:track:4G9mDvbxpmMNFNXXlLbEot
# 43   0rlFL6bxIWcCn9gk9GExFA  spotify:track:0rlFL6bxIWcCn9gk9GExFA
# 247  4XmwxMblrHFWIXurJmFWD3  spotify:track:4XmwxMblrHFWIXurJmFWD3
# 315  2QZBf5Rq9bCHFt7j95G4w2  spotify:track:2QZBf5Rq9bCHFt7j95G4w2
#
#                                             track_href  \
# 18   https://api.spotify.com/v1/tracks/7jhS5XE7nmgc...
# 22   https://api.spotify.com/v1/tracks/5KmA68mgrZX8...
# 31   https://api.spotify.com/v1/tracks/3LRddJIw2ymm...
# 35   https://api.spotify.com/v1/tracks/4G9mDvbxpmMN...
# 43   https://api.spotify.com/v1/tracks/0rlFL6bxIWcC...
# 247  https://api.spotify.com/v1/tracks/4XmwxMblrHFW...
# 315  https://api.spotify.com/v1/tracks/2QZBf5Rq9bCH...
#
#                                           analysis_url  duration_ms  \
# 18   https://api.spotify.com/v1/audio-analysis/7jhS...       227173
# 22   https://api.spotify.com/v1/audio-analysis/5KmA...       192333
# 31   https://api.spotify.com/v1/audio-analysis/3LRd...       196117
# 35   https://api.spotify.com/v1/audio-analysis/4G9m...       219893
# 43   https://api.spotify.com/v1/audio-analysis/0rlF...       182834
# 247  https://api.spotify.com/v1/audio-analysis/4Xmw...       246787
# 315  https://api.spotify.com/v1/audio-analysis/2QZB...       212290
#
#      time_signature
# 18                5
# 22                5
# 31                5
# 35                5
# 43                5
# 247               5
# 315               5

# %% [markdown]
# A quick listen shows all these are actually in 4/4 time so this is a case of incorrect metadata.
#
# Let's drop the columns we don't need:

# %%
pcdf.drop(['key','mode','track_href','instrumentalness','analysis_url','time_signature','uri','id','type'],axis=1,inplace=True)

# %%
pcdf.head()
# Out:
#    danceability  energy  loudness  speechiness  acousticness  liveness  \
# 0         0.462   0.715    -6.829       0.0454       0.11800    0.0592
# 1         0.678   0.607    -7.190       0.0750       0.17400    0.0788
# 2         0.623   0.840    -3.944       0.0799       0.04730    0.1070
# 3         0.555   0.423    -6.232       0.0440       0.79900    0.1120
# 4         0.420   0.879    -4.916       0.0568       0.00729    0.1800
#
#    valence    tempo  duration_ms
# 0    0.237   99.763       166788
# 1    0.445   91.973       204418
# 2    0.788  162.062       251627
# 3    0.257  137.044       202147
# 4    0.432  128.913       279000

# %% [markdown]
# Much better.
#
# Let's plot everything vs everything else to see if anything interesting pops out:

# %%
sns.pairplot(pcdf)

# %% [markdown]
# Let's directly check correlations:

# %%
plt.figure(figsize=(10,8))
sns.heatmap(pcdf.corr(),annot=True)

# %% [markdown]
# Some observations about the songs on the PopConnoisseur Playlist:
# 1. fairly loud
# 2. not very "speechy"
# 3. not very "live"
# 4. midtempo: mostly between 90 and 140 bpm
# 5. mostly around the same length - 3-4 min
# 6. generally low-valence, which means "gloomy" or "negative"
# 7. some correlation between loudness and energy, which makes sense
# 8. negative correlation between acousticness and both energy and loudness, which again makes sense.

# %% [markdown]
# Now let's look at the Billboard Hot 100:

# %%
bbdf.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.672   0.855    9    -3.764     1       0.0397       0.02100
# 1         0.822   0.743   10    -4.772     0       0.2800       0.01600
# 2         0.746   0.690   11    -7.956     1       0.1640       0.24700
# 3         0.514   0.730    1    -5.934     1       0.0598       0.00146
# 4         0.856   0.641   11    -4.640     0       0.2040       0.11900
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000000    0.3230    0.646  123.056  audio_features
# 1          0.000000    0.1270    0.636   84.459  audio_features
# 2          0.000000    0.1010    0.497   89.977  audio_features
# 3          0.000095    0.0897    0.334  171.005  audio_features
# 4          0.000005    0.4270    0.745  111.004  audio_features
#
#                        id                                   uri  \
# 0  24ySl2hOPGCDcxBxFIqWBu  spotify:track:24ySl2hOPGCDcxBxFIqWBu
# 1  5v4GgrXPMghOnBBLmveLac  spotify:track:5v4GgrXPMghOnBBLmveLac
# 2  7ytR5pFWmSjzHJIeQkgog4  spotify:track:7ytR5pFWmSjzHJIeQkgog4
# 3  0VjIjW4GlUZAMYd2vXMi3b  spotify:track:0VjIjW4GlUZAMYd2vXMi3b
# 4  11VApNQCWLJdzxWrlmwzUa  spotify:track:11VApNQCWLJdzxWrlmwzUa
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/24ySl2hOPGCD...
# 1  https://api.spotify.com/v1/tracks/5v4GgrXPMghO...
# 2  https://api.spotify.com/v1/tracks/7ytR5pFWmSjz...
# 3  https://api.spotify.com/v1/tracks/0VjIjW4GlUZA...
# 4  https://api.spotify.com/v1/tracks/11VApNQCWLJd...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/24yS...       182200
# 1  https://api.spotify.com/v1/audio-analysis/5v4G...       242001
# 2  https://api.spotify.com/v1/audio-analysis/7ytR...       181733
# 3  https://api.spotify.com/v1/audio-analysis/0VjI...       200040
# 4  https://api.spotify.com/v1/audio-analysis/11VA...       206221
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
bbdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      100 non-null    float64
#  1   energy            100 non-null    float64
#  2   key               100 non-null    int64
#  3   loudness          100 non-null    float64
#  4   mode              100 non-null    int64
#  5   speechiness       100 non-null    float64
#  6   acousticness      100 non-null    float64
#  7   instrumentalness  100 non-null    float64
#  8   liveness          100 non-null    float64
#  9   valence           100 non-null    float64
#  10  tempo             100 non-null    float64
#  11  type              100 non-null    object
#  12  id                100 non-null    object
#  13  uri               100 non-null    object
#  14  track_href        100 non-null    object
#  15  analysis_url      100 non-null    object
#  16  duration_ms       100 non-null    int64
#  17  time_signature    100 non-null    int64
# dtypes: float64(9), int64(4), object(5)
# memory usage: 14.2+ KB

# %% [markdown]
# As we go, it's worth bearing in mind that the Billboard Hot 100 is just 100 songs vs 362 for PopConnoisseur.

# %%
plt.figure(figsize=(10,4))
sns.distplot(bbdf['instrumentalness'])

# %% [markdown]
# There are virtually no instrumentals on the billboard Hot 100!
#
# How many different values for time signature are there?

# %%
bbdf.time_signature.value_counts()
# Out:
# 4    97
# 3     2
# 1     1
# Name: time_signature, dtype: int64

# %%
# Sure enough, if you check out the 1/4 song:
bbdf[bbdf.time_signature == 1]
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 42         0.778   0.559    6    -7.109     0       0.0776         0.128
#
#     instrumentalness  liveness  valence    tempo            type  \
# 42               0.0     0.399    0.678  129.989  audio_features
#
#                         id                                   uri  \
# 42  7aiClxsDWFRQ0Kzk5KI5ku  spotify:track:7aiClxsDWFRQ0Kzk5KI5ku
#
#                                            track_href  \
# 42  https://api.spotify.com/v1/tracks/7aiClxsDWFRQ...
#
#                                          analysis_url  duration_ms  \
# 42  https://api.spotify.com/v1/audio-analysis/7aiC...       185093
#
#     time_signature
# 42               1

# %% [markdown]
# ...it's "Hot Girl Bummer", which is actually 4/4 time.
#
# Otherwise the playlist is mostly 4/4 time, which sounds right for pop music. Let's drop the columns we don't need:

# %%
bbdf.drop(['key','mode','track_href','instrumentalness','analysis_url','time_signature','uri','id','type'],axis=1,inplace=True)

# %% [markdown]
# Let's check the average values for the two playlists:

# %%
pcdf.mean()
# Out:
# danceability         0.623856
# energy               0.624329
# loudness            -6.808097
# speechiness          0.094267
# acousticness         0.204381
# liveness             0.160218
# valence              0.437906
# tempo              118.237229
# duration_ms     222684.541436
# dtype: float64

# %%
bbdf.mean()
# Out:
# danceability         0.727470
# energy               0.620790
# loudness            -6.537780
# speechiness          0.128553
# acousticness         0.193882
# liveness             0.187433
# valence              0.499516
# tempo              120.670870
# duration_ms     190449.530000
# dtype: float64

# %% [markdown]
# Some observations:
#
# 1. Billboard Hot 100 much more danceable.
# 2. Energy, loudness, liveness, acousticness and tempo roughly comparable.
# 3. PopConnoisseur has longer songs.

# %%
sns.pairplot(bbdf)

# %% [markdown]
# Again, let's directly check correlations:

# %%
plt.figure(figsize=(10,8))
sns.heatmap(bbdf.corr(),annot=True)

# %% [markdown]
# Some observations of songs on the Billboard Hot 100:
# 1. fairly loud
# 2. not very "speechy"
# 3. not very "live"
# 4. midtempo: mostly between 90 and 140 bpm
# 5. a wider variety of tempos than the PopConnoisseur playlist
# 6. valence mostly in the middle
# 7. again, some correlation between loudness and energy, which makes sense
# 8. negative correlation again between acousticness and both energy and loudness
# 9. no real correlation between energy and danceability, which is interesting...
#
# As you can see, there is quite a lot of overlap in these data sets. Let's compare them directly:

# %%
alldf = pd.read_excel('alldata.xlsx', usecols = "B:S")
sns.pairplot(alldf, hue = 'playlist', palette='Dark2')

# %% [markdown]
# Let's try adding in something less similar: Spotify's Ambient Relaxation playlist. You can hear it here:
#
# https://open.spotify.com/playlist/37i9dQZF1DX3Ogo9pFvBkY?si=33qUwYElThG7D5sk83CJlw
#
# I grabbed the songs, then features using Spotipy and the Spotify API and saved it to 'ar_data.xlsx.

# %%
ardf = pd.read_excel('ar_data.xlsx', usecols = "B:S")

# %%
ardf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      289 non-null    float64
#  1   energy            289 non-null    float64
#  2   key               289 non-null    int64
#  3   loudness          289 non-null    float64
#  4   mode              289 non-null    int64
#  5   speechiness       289 non-null    float64
#  6   acousticness      289 non-null    float64
#  7   instrumentalness  289 non-null    float64
#  8   liveness          289 non-null    float64
#  9   valence           289 non-null    float64
#  10  tempo             289 non-null    float64
#  11  type              289 non-null    object
#  12  id                289 non-null    object
#  13  uri               289 non-null    object
#  14  track_href        289 non-null    object
#  15  analysis_url      289 non-null    object
#  16  duration_ms       289 non-null    int64
#  17  time_signature    289 non-null    int64
# dtypes: float64(9), int64(4), object(5)
# memory usage: 40.8+ KB

# %% [markdown]
# As always, we get rid of columns we don't need.

# %%
ardf.drop(['key','mode','track_href','instrumentalness','analysis_url','time_signature','uri','type','id'],axis=1,inplace=True)

# %% [markdown]
# Let's create a new column for merging the two Pop playlists with the Ambient Relaxation Playlist.

# %%
ardf['playlist']=2

# %% [markdown]
# Now let's merge the original two playlists with the new one:

# %%
frames = [alldf, ardf]
alldf2 = pd.concat(frames)

# %% [markdown]
# ...and run a pairplot separated by playlist:

# %%
sns.pairplot(alldf2, hue='playlist')

# %% [markdown]
# Here we have a much more drastic difference! There is very clear separation in most features as the Ambient Relaxation playlist, in green.
#
# Let's look at them all together:

# %%
alldf2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 751 entries, 0 to 288
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   danceability  751 non-null    float64
#  1   energy        751 non-null    float64
#  2   loudness      751 non-null    float64
#  3   speechiness   751 non-null    float64
#  4   acousticness  751 non-null    float64
#  5   liveness      751 non-null    float64
#  6   valence       751 non-null    float64
#  7   tempo         751 non-null    float64
#  8   duration_ms   751 non-null    int64
#  9   playlist      751 non-null    int64
# dtypes: float64(8), int64(2)
# memory usage: 84.5 KB

# %% [markdown]
# Let's compare danceability of the three playlists. Bear in mind there are fewer Billboard songs.

# %%
plt.figure(figsize=(10,6))
scale_pc = (1 / 3.62)
scale_ar = (1 / 2.89)

alldf2[alldf2['playlist']==1]['danceability'].hist(bins=35, color='orange',label='PopConnoisseur',alpha=0.6)
alldf2[alldf2['playlist']==2]['danceability'].hist(bins=35, color='green',label='Ambient',alpha=0.6)
alldf2[alldf2['playlist']==0]['danceability'].hist(bins=35, color='blue',label='Billboard',alpha=0.6)

plt.legend()
plt.xlabel('Danceability')
# Out:
# Text(0.5, 0, 'Danceability')

# %% [markdown]
# Let's compare acousticness of the three playlists.

# %%
plt.figure(figsize=(10,6))
alldf2[alldf2['playlist']==1]['acousticness'].hist(bins=35, color='orange',label='PopConnoisseur',alpha=0.6)
alldf2[alldf2['playlist']==2]['acousticness'].hist(bins=35, color='green',label='Acoustic',alpha=0.6)
alldf2[alldf2['playlist']==0]['acousticness'].hist(bins=35, color='blue',label='Billboard',alpha=0.6)
plt.legend()
plt.xlabel('Acousticness')
# Out:
# Text(0.5, 0, 'Acousticness')

# %% [markdown]
# There's not a big enough difference between Billboard and PopConn so let's create a new column merging both.

# %%
alldf2['pl2'] = [0 if x == 2 else 1 for x in alldf2['playlist']]

# %% [markdown]
# Now let's do some Machine Learning.
#
# Let's train/test/split to predict the loudness value.

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# For X let's use two columns that have the strongest negative correlation.

# %%
X = alldf2[['energy','acousticness']].values
y = alldf2['loudness'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# Let's scale the data - but JUST the X data! - for the neural network:

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# Now it's time to actually create the neural network!

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# Let's define a callback function that cancels when a loss of 5 is reached:

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('loss')<5):
      print("\nReached loss of 5 so cancelling training!")
      self.model.stop_training = True
callbacks = myCallback()

# %% [markdown]
# We'll use Adam as our optimizer and MSE as our error metric.

# %%
model = Sequential()

model.add(Dense(32,activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')

# %% [markdown]
# Then let's run it!

# %%
model.fit(x=X_train, y=y_train,epochs=250, callbacks=[callbacks])
# Out:
# Epoch 1/250
# 17/17 [==============================] - 0s 3ms/step - loss: 263.3637
# Epoch 2/250
# 17/17 [==============================] - 0s 2ms/step - loss: 259.1347
# Epoch 3/250
# 17/17 [==============================] - 0s 3ms/step - loss: 253.1792
# Epoch 4/250
# 17/17 [==============================] - 0s 4ms/step - loss: 244.1529
# Epoch 5/250
# 17/17 [==============================] - 0s 4ms/step - loss: 231.1368
# Epoch 6/250
# 17/17 [==============================] - 0s 4ms/step - loss: 213.6517
# Epoch 7/250
# 17/17 [==============================] - 0s 5ms/step - loss: 191.6093
# Epoch 8/250
# 17/17 [==============================] - 0s 3ms/step - loss: 165.2312
# Epoch 9/250
250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.8502
# Epoch 205/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.8559
# Epoch 206/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.8230
# Epoch 207/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.8493
# Epoch 208/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.8113
# Epoch 209/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.8232
# Epoch 210/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.7993
# Epoch 211/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.9020
# Epoch 212/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.8347
# Epoch 213/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.7928
# Epoch 214/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.7879
# Epoch 215/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.7794
# Epoch 216/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.7903
# Epoch 217/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.7709
# Epoch 218/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.7320
# Epoch 219/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.8023
# Epoch 220/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.7750
# Epoch 221/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.7778
# Epoch 222/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.7357
# Epoch 223/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.7562
# Epoch 224/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.7346
# Epoch 225/250
# 17/17 [==============================] - 0s 7ms/step - loss: 7.7679
# Epoch 226/250
# 17/17 [==============================] - 0s 8ms/step - loss: 7.7420
# Epoch 227/250
# 17/17 [==============================] - 0s 3ms/step - loss: 7.7789
# Epoch 228/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.7066
# Epoch 229/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.7223
# Epoch 230/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.8245
# Epoch 231/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.7183
# Epoch 232/250
# 17/17 [==============================] - 0s 1ms/step - loss: 7.7459
# Epoch 233/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.7374
# Epoch 234/250
# 17/17 [==============================] - 0s 1ms/step - loss: 7.7243
# Epoch 235/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.7061
# Epoch 236/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.7045
# Epoch 237/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.8036
# Epoch 238/250
# 17/17 [==============================] - 0s 7ms/step - loss: 7.7145
# Epoch 239/250
# 17/17 [==============================] - 0s 4ms/step - loss: 7.7383
# Epoch 240/250
# 17/17 [==============================] - 0s 5ms/step - loss: 7.7121
# Epoch 241/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.7245
# Epoch 242/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.7801
# Epoch 243/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.7622
# Epoch 244/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.7165
# Epoch 245/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.6724
# Epoch 246/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.7829
# Epoch 247/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.6834
# Epoch 248/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.7146
# Epoch 249/250
# 17/17 [==============================] - 0s 2ms/step - loss: 7.6784
# Epoch 250/250
# 17/17 [==============================] - 0s 5ms/step - loss: 7.6784

# %% [markdown]
# Some experimenting:
# - I tried with up to 1000 epochs but 250 was more than enough.
# - Two layers was good but four was better.
# - 'adam' just nudged ahead of 'rmsprop' for optimizer.
# - I set callback at a loss of 5, just for kicks, but didn't end up hitting it.
# - I tried 128 neurons in that first layer but it was overkill - 32 is plenty.
#
# Let's plot our loss:

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot()

# %% [markdown]
# Let's evaluate the Mean Squared Error:

# %%
model.evaluate(X_train,y_train,verbose=0)
# Out:
# 7.646534442901611

# %% [markdown]
# Let's get the actual data:

# %%
test_predictions = model.predict(X_test)
test_predictions
# Out:
# array([[-28.798695 ],
#        [ -5.558884 ],
#        [ -6.97686  ],
#        [ -6.691852 ],
#        [ -6.770565 ],
#        [-27.127277 ],
#        [ -5.3932204],
#        [ -4.4219294],
#        [-23.450424 ],
#        [-27.776697 ],
#        [ -5.75661  ],
#        [ -6.0523596],
#        [ -4.723972 ],
#        [-25.48279  ],
#        [ -4.1789193],
#        [ -4.8862123],
#        [ -7.5173903],
#        [ -7.1053734],
#        [ -4.5870275],
#        [-26.78196  ],
#        [-25.19225  ],
#        [-23.445974 ],
#        [ -5.629401 ],
#        [ -8.103475 ],
#        [ -6.3941054],
#        [-22.540085 ],
#        [ -4.8329005],
#        [ -4.454859 ],
#        [ -5.2572002],
#        [ -9.561287 ],
#        [ -5.9155164],
#        [-27.728825 ],
#        [ -8.249836 ],
#        [ -7.177847 ],
#        [ -7.0910726],
#        [ -9.724653 ],
#        [ -4.3810983],
#        [ -6.7973933],
#        [ -8.429177 ],
#        [-20.201973 ],
#        [ -7.5626974],
#        [-26.212845 ],
#        [ -4.568577 ],
#        [-13.92228  ],
#        [ -5.7737226],
#        [-28.509846 ],
#        [-25.51078  ],
#        [-23.048193 ],
#        [ -5.6764803],
#        [-15.716243 ],
#        [ -6.0236454],
#        [-26.730192 ],
#        [ -5.1856914],
#        [ -5.8113575],
#        [-17.74577  ],
#        [ -6.820865 ],
#        [-18.481365 ],
#        [ -5.9729667],
#        [-23.271591 ],
#        [ -8.058933 ],
#        [ -5.83723  ],
#        [ -6.156903 ],
#        [-28.233006 ],
#        [-24.102459 ],
#        [ -6.028937 ],
#        [ -4.832531 ],
#        [ -8.7348385],
#        [ -4.3154335],
#        [ -5.5132875],
#        [-29.08685  ],
#        [-27.467365 ],
#        [ -7.488848 ],
#        [ -9.998778 ],
#        [-27.843098 ],
#        [-19.70097  ],
#        [ -6.1522417],
#        [ -7.330202 ],
#        [ -6.440071 ],
#        [ -5.457097 ],
#        [ -6.897462 ],
#        [ -5.013421 ],
#        [ -6.949596 ],
#        [-27.195911 ],
#        [-18.012672 ],
#        [ -8.519318 ],
#        [ -5.907207 ],
#        [-13.443113 ],
#        [ -7.2848444],
#        [-16.523714 ],
#        [ -4.831863 ],
#        [-18.189423 ],
#        [ -5.1999083],
#        [-26.95175  ],
#        [-28.43228  ],
#        [ -3.4736636],
#        [ -4.861869 ],
#        [-27.21369  ],
#        [-15.584983 ],
#        [ -5.3203263],
#        [ -7.4025517],
#        [ -6.71114  ],
#        [-19.267895 ],
#        [ -4.709777 ],
#        [-29.159863 ],
#        [ -5.549568 ],
#        [ -7.513275 ],
#        [-22.469334 ],
#        [-28.980228 ],
#        [-24.789865 ],
#        [ -6.1389623],
#        [-22.46341  ],
#        [ -7.8826833],
#        [ -4.027729 ],
#        [-28.756655 ],
#        [-23.75874  ],
#        [-26.426674 ],
#        [-19.558205 ],
#        [ -5.298991 ],
#        [-25.670973 ],
#        [ -3.9774904],
#        [ -6.5047917],
#        [ -4.633009 ],
#        [-24.64593  ],
#        [ -6.7663107],
#        [-20.858894 ],
#        [-15.413707 ],
#        [ -6.4080043],
#        [-21.549227 ],
#        [ -8.3548765],
#        [-19.258135 ],
#        [ -7.3168654],
#        [ -4.7898264],
#        [ -7.800792 ],
#        [-19.257317 ],
#        [-28.961596 ],
#        [-11.222384 ],
#        [ -9.065173 ],
#        [ -5.451843 ],
#        [ -5.454945 ],
#        [-14.015105 ],
#        [ -4.420759 ],
#        [ -8.134385 ],
#        [-20.694725 ],
#        [ -7.1162386],
#        [ -5.963587 ],
#        [-26.525696 ],
#        [ -6.300058 ],
#        [ -4.6493077],
#        [-22.24234  ],
#        [ -5.296892 ],
#        [-28.315477 ],
#        [ -4.6731844],
#        [ -6.3196397],
#        [ -8.420647 ],
#        [-19.154217 ],
#        [ -8.315161 ],
#        [ -6.6361456],
#        [-19.122278 ],
#        [ -6.563822 ],
#        [-19.893526 ],
#        [ -7.826982 ],
#        [-22.818626 ],
#        [ -8.3226795],
#        [-24.946972 ],
#        [ -6.825452 ],
#        [-24.603092 ],
#        [ -6.0510583],
#        [-28.974    ],
#        [ -4.3324103],
#        [ -6.0811996],
#        [ -6.5112443],
#        [ -4.9842744],
#        [ -5.7335386],
#        [-11.117129 ],
#        [ -9.286691 ],
#        [ -7.245295 ],
#        [-25.542791 ],
#        [-16.257957 ],
#        [ -7.417555 ],
#        [ -7.8846283],
#        [-20.409317 ],
#        [ -8.63122  ],
#        [ -8.045839 ],
#        [-27.920156 ],
#        [ -4.7714334],
#        [-23.692698 ],
#        [ -7.316409 ],
#        [ -5.8524127],
#        [-27.568254 ],
#        [-21.30696  ],
#        [-23.762657 ],
#        [ -7.553752 ],
#        [-26.820154 ],
#        [-17.759739 ],
#        [ -5.1003942],
#        [ -5.6921687],
#        [-21.378073 ],
#        [-28.431347 ],
#        [-22.510998 ],
#        [-27.176506 ],
#        [ -5.890524 ],
#        [-20.304134 ],
#        [ -5.7688293],
#        [-27.563404 ],
#        [-28.851265 ],
#        [ -6.4589   ],
#        [-24.105473 ],
#        [ -9.454674 ],
#        [ -3.8087583],
#        [-20.943245 ],
#        [ -5.9092197],
#        [ -6.013138 ],
#        [-25.00841  ],
#        [ -7.5604134],
#        [-11.294113 ],
#        [-21.590523 ],
#        [ -6.1366415],
#        [ -6.942219 ],
#        [ -3.8177726],
#        [-14.204873 ],
#        [ -8.058659 ],
#        [-27.656857 ],
#        [-10.634744 ],
#        [ -5.4586124],
#        [ -7.299613 ],
#        [ -8.6199255]], dtype=float32)

# %% [markdown]
# We'll need to reshape the data to fit, then we can compare predictions vs actual Y values:

# %%
test_predictions = pd.Series(test_predictions.reshape(226,))
pred_df = pd.DataFrame(y_test,columns=['Test True Y'])
pred_df = pd.concat([pred_df,test_predictions],axis=1)
pred_df.columns = ['Test True Y','Model Predictions']
pred_df
# Out:
#      Test True Y  Model Predictions
# 0        -31.238         -28.798695
# 1         -5.131          -5.558884
# 2         -8.079          -6.976860
# 3         -8.530          -6.691852
# 4         -4.924          -6.770565
# ..           ...                ...
# 221      -32.056         -27.656857
# 222       -5.810         -10.634744
# 223       -4.258          -5.458612
# 224       -7.503          -7.299613
# 225       -8.756          -8.619925
#
# [226 rows x 2 columns]

# %%
sns.scatterplot(x='Test True Y',y='Model Predictions',data=pred_df)

# %% [markdown]
# Not perfect - a straight diagonal line - but in the right general direction. More data would probably help.
#
# Let's check the MAE.

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(pred_df['Test True Y'],pred_df['Model Predictions'])
# Out:
# 1.944663796796208

# %% [markdown]
# Let's try a new model, using Support Vector Machines (SVC):

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %% [markdown]
# We can train/test/split to predict the playlist value, i.e. which playlist is a given song in.

# %%
model = SVC()

# %% [markdown]
# That means we have to redefine X to all columns EXCEPT 'playlist' and y to just 'playlist':

# %%
X = alldf2.drop('pl2',axis=1)
y = alldf2['pl2']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model.fit(X_train,y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %% [markdown]
# Model Evaluation

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %% [markdown]
# Let's check out a Confusion Matrix:

# %%
print(confusion_matrix(y_test, predictions))
# Out:
# [[ 18  67]
#  [  4 137]]

# %% [markdown]
# This is not that impressive but let's try a Classification Report.

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.21      0.34        85
#            1       0.67      0.97      0.79       141
#
#     accuracy                           0.69       226
#    macro avg       0.74      0.59      0.57       226
# weighted avg       0.73      0.69      0.62       226

# %% [markdown]
# At this point, in the real world, I tried a GridSearch and got even worse results, so I moved on to Decision Trees/Random Forests. Let's try Decision Trees first:

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# We'll have to redefine X and y, then train/test/split again:

# %%
alldf2['pl2'].value_counts()
# Out:
# 1    462
# 0    289
# Name: pl2, dtype: int64

# %%
X = alldf2.drop('pl2',axis=1)
y = alldf2['pl2']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
dtree = DecisionTreeClassifier()
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
predictions = dtree.predict(X_test)

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        88
#            1       1.00      1.00      1.00       138
#
#     accuracy                           1.00       226
#    macro avg       1.00      1.00      1.00       226
# weighted avg       1.00      1.00      1.00       226

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[ 88   0]
#  [  0 138]]

# %% [markdown]
# Perfect results! That's pretty impressive! Let's try the same thing with just the two original pop playlists:

# %%
X = alldf.drop('playlist',axis=1)
y = alldf['playlist']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
dtree = DecisionTreeClassifier()
dtree.fit(X_train,y_train)
predictions = dtree.predict(X_test)
print(classification_report(y_test,predictions))
print(confusion_matrix(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.42      0.33      0.37        30
#            1       0.83      0.87      0.85       109
#
#     accuracy                           0.76       139
#    macro avg       0.62      0.60      0.61       139
# weighted avg       0.74      0.76      0.75       139
#
# [[10 20]
#  [14 95]]

# %% [markdown]
# Definitely not bad, and the confusion matrix looks passable.
#
# Let's try Random Forests:

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=100)

# %%
X = alldf2.drop('pl2',axis=1)
y = alldf2['pl2']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rfc_pred = rfc.predict(X_test)

# %%
print(classification_report(y_test,rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        83
#            1       1.00      1.00      1.00       143
#
#     accuracy                           1.00       226
#    macro avg       1.00      1.00      1.00       226
# weighted avg       1.00      1.00      1.00       226

# %%
print(confusion_matrix(y_test,rfc_pred))
# Out:
# [[ 83   0]
#  [  0 143]]

# %% [markdown]
# Again, Random Forests makes it look easy!
#
# Let's try that with the original two playlists:

# %%
X = alldf.drop('playlist',axis=1)
y = alldf['playlist']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)
rfc.fit(X_train, y_train)
rfc_pred = rfc.predict(X_test)
print(classification_report(y_test,rfc_pred))
print(confusion_matrix(y_test,rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.34      0.44        29
#            1       0.85      0.95      0.89       110
#
#     accuracy                           0.82       139
#    macro avg       0.74      0.65      0.67       139
# weighted avg       0.80      0.82      0.80       139
#
# [[ 10  19]
#  [  6 104]]

# %% [markdown]
# This f1-score and confusion matrix result is a bit better across the board. There has been a lot written about adjusting Random Forect hyperparameters. I've just gone with defaults/"typical" values here, but it could be worth some experimentation in the future, along the lines of this article:
#
# https://towardsdatascience.com/optimizing-hyperparameters-in-random-forest-classification-ec7741f9d3f6

# %% [markdown]
# Thanks for reading this far!
